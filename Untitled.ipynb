# %%
import requests
import pandas as pd
import json
from dateutil import parser
import re
from rich.progress import track

headers = {
    "accept": "application/json, text/plain, */*",
    "accept-language": "zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6",
    "priority": "u=1, i",
    "sec-ch-ua": '"Not/A)Brand";v="8", "Chromium";v="126", "Microsoft Edge";v="126"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0",
    "x-requested-with": "XMLHttpRequest",
    # 可能会修改的地方
    "cookie": "SINAGLOBAL=8518412904158.368.1713933172488; SUB=_2A25La68FDeRhGeFJ4lIT9CzNyj6IHXVoCK7NrDV8PUNbmtANLXetkW9NfsmQ4Qz8zDr0mXZfri_ta_ZUdx1oaRtm; ALF=02_1721199701; _s_tentry=www.weibo.com; Apache=2102778680934.707.1718678424260; XSRF-TOKEN=PRz0XbyfMJG4mq7eMDRnCAPT; ULV=1718678424414:3:2:2:2102778680934.707.1718678424260:1718607749265; WBPSESS=2bPq4LTfaY-EnTnt8h5hWX9KGoz50scMNqd4lpDCT8IiCLnpv2C9Z_Kk8JVbYkIyBQ0eFNYccRFpnV_A6ntYbzFhGRa6K_Y0y_9c3zhS6S73tx-mc1RjJ-zr1RH9K8LXJeEA0KnwBx7zuzsiTaBcug==",
}


def get_buildComments_response(uid, mid, the_first=True, max_id=None):
    params = {
        "is_reload": "1",
        "id": f"{mid}",
        "is_show_bulletin": "2",
        "is_mix": "0",
        "count": "20",
        "uid": f"{uid}",
        "fetch_level": "0",
        "locale": "zh-CN",
    }

    if not the_first:
        params["flow"] = 0
        params["max_id"] = max_id

    response = requests.get(
        "https://weibo.com/ajax/statuses/buildComments", params=params, headers=headers
    )
    return response


def get_rum_response(buildComments_url):
    entry = {"name": buildComments_url}
    files = {
        "entry": (None, json.dumps(entry)),
        "request_id": (None, ""),
    }
    # 这个resp返回值无实际意义，返回值一直是{ok: 1}
    requests.post("https://weibo.com/ajax/log/rum", headers=headers, files=files)


def get_level_one_response(uid, mid, the_first=True, max_id=None):
    buildComments_resp = get_buildComments_response(uid, mid, the_first, max_id)
    buildComments_url = buildComments_resp.url
    get_rum_response(buildComments_url)
    data = pd.DataFrame(buildComments_resp.json()["data"])
    max_id = buildComments_resp.json()["max_id"]
    return max_id, data


def get_all_level_one(uid, mid):
    # 初始化
    max_id = ""
    data_lst = []
    max_times = 3  # 最多只有15页

    for current_times in track(range(1, max_times)):
        if current_times == 0:
            max_id, data = get_level_one_response(uid=uid, mid=mid)
        else:
            max_id, data = get_level_one_response(
                uid=uid, mid=mid, the_first=False, max_id=max_id
            )
        if data.shape[0] == 0 or max_id == 0:
            break
        else:
            data_lst.append(data)
    data = pd.concat(data_lst).reset_index(drop=True)
    return data

# %%
name = "#邹振东诚邀张雪峰来厦门请你吃沙茶面#"
uid = "2610806555"
mid = "4914095331742409"

data = get_all_level_one(uid, mid)
data.head(1)
# Out:
# C:\miniconda\envs\analyze\lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                        created_at                id            rootid  \
# 0  Sun Jun 18 22:18:59 +0800 2023  4914107285767925  4914107285767925
#
#           rootidstr  floor_number  \
# 0  4914107285767925            38
#
#                                                 text  disable_reply  \
# 0  那么问题来了，如果你家孩子或者亲戚家孩子，理科590，如果有赋分，得600好几十分，能有一大...              0
#
#    restrictOperate  source_allowclick  source_type  ...  \
# 0                0                  0            4  ...
#
# ...

# %%
def process_time(publish_time):
    publish_time = parser.parse(publish_time)
    publish_time = publish_time.strftime('%y年%m月%d日 %H:%M')
    return publish_time

data_user = pd.json_normalize(data['user'])
data_user = data_user[['id','screen_name','profile_url','description','location','gender','followers_count','friends_count','statuses_count', 'status_total_counter.comment_cnt','status_total_counter.repost_cnt','status_total_counter.like_cnt','status_total_counter.total_cnt','verified_reason']]
data_user.columns = ['uid', '用户昵称', '用户主页', '用户描述', '用户地理位置', '用户性别', '用户粉丝数量', '用户关注数量', '用户全部微博', '用户累计评论', '用户累计转发', '用户累计获赞', '用户转评赞', '用户认证信息']
data_main = data[['created_at', 'text', 'source', 'mid', 'total_number', 'like_counts', 'text_raw']]
data_main.columns = ['发布时间', '处理内容', '评论地点', 'mid', '回复数量', '点赞数量', '原生内容']
data = pd.concat([data_main, data_user], axis=1)
data['发布时间'] = data['发布时间'].map(process_time)
data['用户主页'] = 'https://weibo.com' + data['用户主页']
data.head(3)
# Out:
#               发布时间                                               处理内容  评论地点  \
# 0  23年06月18日 22:18  那么问题来了，如果你家孩子或者亲戚家孩子，理科590，如果有赋分，得600好几十分，能有一大...  来自安徽
# 1  23年06月18日 23:52  我非常感佩张雪峰站在普通人的立场为考生与家长提供良心的建议，我在文中也写到尊重考生与家长现实...  来自福建
# 2  23年06月18日 23:54  我只知道我自己的研究生，每年我要花一个学期的时间，帮助一届一届毕业生就业，他们每一次崩溃都会...  来自福建
#
#                 mid  回复数量  点赞数量  \
# 0  4914107285767925   951  2520
# 1  4914130898913588   522  1341
# 2  4914131230787423   263   899
#
#                                                 原生内容         uid         用户昵称  \
# 0  那么问题来了，如果你家孩子或者亲戚家孩子，理科590，如果有赋分，得600好几十分，能有一大...  1695290860  牛油果的核是怎么形成的
# 1  我非常感佩张雪峰站在普通人的立场为考生与家长提供良心的建议，我在文中也写到尊重考生与家长现实...  2610806555          邹振东
# 2  我只知道我自己的研究生，每年我要花一个学期的时间，帮助一届一届毕业生就业，他们每一次崩溃都会...  2610806555          邹振东
#
#                              用户主页  ... 用户地理位置 用户性别  用户粉丝数量  用户关注数量  用户全部微博  \
# 0  https://weibo.com/u/1695290860  ...  江苏 南京    f     235     152    1076
# ...

# %%
import requests
import pandas as pd
import json
from rich.progress import track
from dateutil import parser

headers = {
    "accept": "application/json, text/plain, */*",
    "accept-language": "zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6",
    "priority": "u=1, i",
    "sec-ch-ua": '"Not/A)Brand";v="8", "Chromium";v="126", "Microsoft Edge";v="126"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0",
    "x-requested-with": "XMLHttpRequest",
    # 可能会修改的地方
    "cookie": "SINAGLOBAL=8518412904158.368.1713933172488; SUB=_2A25La68FDeRhGeFJ4lIT9CzNyj6IHXVoCK7NrDV8PUNbmtANLXetkW9NfsmQ4Qz8zDr0mXZfri_ta_ZUdx1oaRtm; ALF=02_1721199701; _s_tentry=www.weibo.com; Apache=2102778680934.707.1718678424260; XSRF-TOKEN=PRz0XbyfMJG4mq7eMDRnCAPT; ULV=1718678424414:3:2:2:2102778680934.707.1718678424260:1718607749265; WBPSESS=2bPq4LTfaY-EnTnt8h5hWX9KGoz50scMNqd4lpDCT8IiCLnpv2C9Z_Kk8JVbYkIyBQ0eFNYccRFpnV_A6ntYbzFhGRa6K_Y0y_9c3zhS6S73tx-mc1RjJ-zr1RH9K8LXJeEA0KnwBx7zuzsiTaBcug==",
}


def get_buildComments_response(uid, mid, the_first=True, max_id=None):
    params = {
        'is_reload': '1',
        'id': f'{mid}',
        'is_show_bulletin': '2',
        'is_mix': '1',
        'fetch_level': '1',
        'max_id': '0',
        'count': '20',
        'uid': f'{uid}',
        'locale': 'zh-CN',
    }

    if not the_first:
        params["flow"] = 0
        params["max_id"] = max_id

    response = requests.get(
        "https://weibo.com/ajax/statuses/buildComments", params=params, headers=headers
    )
    return response


def get_rum_response(buildComments_url):
    entry = {"name": buildComments_url}
    files = {
        "entry": (None, json.dumps(entry)),
        "request_id": (None, ""),
    }
    # 这个resp返回值无实际意义，返回值一直是{ok: 1}
    requests.post("https://weibo.com/ajax/log/rum", headers=headers, files=files)


def get_level_one_response(uid, mid, the_first=True, max_id=None):
    buildComments_resp = get_buildComments_response(uid, mid, the_first, max_id)
    buildComments_url = buildComments_resp.url
    get_rum_response(buildComments_url)
    data = pd.DataFrame(buildComments_resp.json()["data"])
    max_id = buildComments_resp.json()["max_id"]
    return max_id, data


def process_time(publish_time):
    publish_time = parser.parse(publish_time)
    publish_time = publish_time.strftime("%y年%m月%d日 %H:%M")
    return publish_time


def process_data(data):
    data_user = pd.json_normalize(data["user"])
    data_user = data_user[
        [
            "id",
            "screen_name",
            "profile_url",
            "description",
            "location",
            "gender",
            "followers_count",
            "friends_count",
            "statuses_count",
            "status_total_counter.comment_cnt",
            "status_total_counter.repost_cnt",
            "status_total_counter.like_cnt",
            "status_total_counter.total_cnt",
            "verified_reason",
        ]
    ]
    data_user.columns = [
        "uid",
        "用户昵称",
        "用户主页",
        "用户描述",
        "用户地理位置",
        "用户性别",
        "用户粉丝数量",
        "用户关注数量",
        "用户全部微博",
        "用户累计评论",
        "用户累计转发",
        "用户累计获赞",
        "用户转评赞",
        "用户认证信息",
    ]
    data_main = data[
        [
            "created_at",
            "text",
            "source",
            "mid",
            "like_counts",
            "text_raw",
        ]
    ]
    data_main.columns = [
        "发布时间",
        "处理内容",
        "评论地点",
        "mid",
        "点赞数量",
        "原生内容",
    ]
    data = pd.concat([data_main, data_user], axis=1)
    data["发布时间"] = data["发布时间"].map(process_time)
    data["用户主页"] = "https://weibo.com" + data["用户主页"]
    return data


def get_all_level_one(uid, mid, max_times=15):
    # 初始化
    max_id = ""
    data_lst = []
    max_times = max_times  # 最多只有15页

    for current_times in track(range(1, max_times)):
        if current_times == 0:
            max_id, data = get_level_one_response(uid=uid, mid=mid)
        else:
            max_id, data = get_level_one_response(
                uid=uid, mid=mid, the_first=False, max_id=max_id
            )
        if data.shape[0] == 0 or max_id == 0:
            break
        else:
            data_lst.append(data)
    data = pd.concat(data_lst).reset_index(drop=True)
    data = process_data(data)
    data.insert(0, "main_body_uid", uid)
    data.insert(0, "comment_level_one_mid", mid)
    return data

# %%
main_body_uid = "2656274875"
mid = "5046022789400609"

data = get_all_level_one(main_body_uid, mid)
# Out:
# C:\miniconda\envs\analyze\lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
data.shape
# Out:
# (120, 22)

# %%
a = [
            "created_at",
            "text",
            "source",
            "mid",
            "total_number",
            "like_counts",
            "text_raw",
        ]

b =  [
        "发布时间",
        "处理内容",
        "评论地点",
        "mid",
        "回复数量",
        "点赞数量",
        "原生内容",
    ]

# %%
dict(zip(a,b))
# Out:
# {'created_at': '发布时间',
#  'text': '处理内容',
#  'source': '评论地点',
#  'mid': 'mid',
#  'total_number': '回复数量',
#  'like_counts': '点赞数量',
#  'text_raw': '原生内容'}

# %%
def process_data(data):
    data_user = pd.json_normalize(data["user"])
    data_user_col_map = {'id': 'uid',
     'screen_name': '用户昵称',
     'profile_url': '用户主页',
     'description': '用户描述',
     'location': '用户地理位置',
     'gender': '用户性别',
     'followers_count': '用户粉丝数量',
     'friends_count': '用户关注数量',
     'statuses_count': '用户全部微博',
     'status_total_counter.comment_cnt': '用户累计评论',
     'status_total_counter.repost_cnt': '用户累计转发',
     'status_total_counter.like_cnt': '用户累计获赞',
     'status_total_counter.total_cnt': '用户转评赞',
     'verified_reason': '用户认证信息'}

    data_user_col = [col for col in data_user if col in data_user_col_map.keys()]
    
    data_user = data_user[data_user_col]
    data_user.rename(columns=data_user_col_map)

    data_main_col_map = {'created_at': '发布时间',
 'text': '处理内容',
 'source': '评论地点',
 'mid': 'mid',
 'total_number': '回复数量',
 'like_counts': '点赞数量',
 'text_raw': '原生内容'}

    data_main_col = [col for col in data if col in data_main_col_map.keys()]
    
    data_main = data[data_main_col]
    data_main.rename(columns=data_main_col_map)
    
    data = pd.concat([data_main, data_user], axis=1)
    data["发布时间"] = data["发布时间"].map(process_time)
    data["用户主页"] = "https://weibo.com" + data["用户主页"]
    return data

# %%
import pandas as pd

# %%
data = pd.read_csv('user.csv')
data_user = data

# %%
data
# Out:
#     Unnamed: 0          id       idstr  pc_new      screen_name  \
# 0            0  1695290860  1695290860       0      牛油果的核是怎么形成的
# 1            1  2610806555  2610806555       7              邹振东
# 2            2  2610806555  2610806555       7              邹振东
# 3            3  2610806555  2610806555       7              邹振东
# 4            4  2610806555  2610806555       7              邹振东
# 5            5  2610806555  2610806555       7              邹振东
# 6            6  3442139262  3442139262       0             粟米一条
# 7            7  6140715470  6140715470       7         WAllines
# 8            8  3974207158  3974207158       7           超级有钱孩-
# 9            9  2511717202  2511717202       7         被茶派击败的胖子
# 10          10  1876315227  1876315227       0             肖老实-
# 11          11  5651803677  5651803677       0            百万分一吨
# 12          12  7628472203  7628472203       7         EvanPlay
# 13          13  1896137513  1896137513       6           看看热热闹闹
# ...

# %%
data_user_col_map = {'id': 'uid',
     'screen_name': '用户昵称',
     'profile_url': '用户主页',
     'description': '用户描述',
     'location': '用户地理位置',
     'gender': '用户性别',
     'followers_count': '用户粉丝数量',
     'friends_count': '用户关注数量',
     'statuses_count': '用户全部微博',
     'status_total_counter.comment_cnt': '用户累计评论',
     'status_total_counter.repost_cnt': '用户累计转发',
     'status_total_counter.like_cnt': '用户累计获赞',
     'status_total_counter.total_cnt': '用户转评赞',
     'verified_reason': '用户认证信息'}

data_user_col = [col for col in data_user if col in data_user_col_map.keys()]

data_user = data_user[data_user_col]
data_user.rename(columns=data_user_col_map)

aa = data_user.rename(columns=data_user_col_map)

# %%
aa.shape
# Out:
# (37, 14)

# %%
a = [1, 2, 3]

# %%
pd.DataFrame([a,a,a]).drop_duplicates()
# Out:
#    0  1  2
# 0  1  2  3
